# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-7, 2.5e-7, 5e-7]
regularization_strengths = [7.5e4, 1e5, 5e5, 1e6]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
num_iter = 500

svms = {}

for lr in learning_rates:
    for C in regularization_strengths:
        svm = LinearSVM()
        # train
        svm.train(X_train_feats, y_train, learning_rate=lr, reg=C, 
                  num_iters=num_iter, verbose=False)
        # predict
        y_train_pred = svm.predict(X_train_feats)
        y_val_pred = svm.predict(X_val_feats)
        # scoring
        train_score = np.mean(y_train == y_train_pred)
        val_score = np.mean(y_val == y_val_pred)
        # store results
        results[(lr, C)] = (train_score, val_score)
        svms[(lr, C)] = svm

sorted_results = sorted(results.items(), key=lambda x: x[1][1]) # by val score
best_params = sorted_results[-1][0]
best_val = sorted_results[-1][1][1]
best_svm = svms[best_params]
print(best_svm.lr, best_svm.C)
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# 1e-07 500000.0
# lr 1.000000e-07 reg 7.500000e+04 train accuracy: 0.407000 val accuracy: 0.400000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.418673 val accuracy: 0.426000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.414571 val accuracy: 0.427000
# lr 1.000000e-07 reg 1.000000e+06 train accuracy: 0.401327 val accuracy: 0.405000
# lr 2.500000e-07 reg 7.500000e+04 train accuracy: 0.418184 val accuracy: 0.423000
# lr 2.500000e-07 reg 1.000000e+05 train accuracy: 0.399184 val accuracy: 0.390000
# lr 2.500000e-07 reg 5.000000e+05 train accuracy: 0.391714 val accuracy: 0.388000
# lr 2.500000e-07 reg 1.000000e+06 train accuracy: 0.369469 val accuracy: 0.359000
# lr 5.000000e-07 reg 7.500000e+04 train accuracy: 0.410082 val accuracy: 0.423000
# lr 5.000000e-07 reg 1.000000e+05 train accuracy: 0.393776 val accuracy: 0.377000
# lr 5.000000e-07 reg 5.000000e+05 train accuracy: 0.354694 val accuracy: 0.355000
# lr 5.000000e-07 reg 1.000000e+06 train accuracy: 0.347429 val accuracy: 0.330000
# best validation accuracy achieved during cross-validation: 0.427000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.438

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
# Yes, they do. Let's take for instance the 'ship' category. As you can see, the model classifies objects that have something blueish on the background which most of the images of ships do. The same applies for deer that probably captured in a forest with green background.

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print(X_train_feats.shape)
# Out:
# (49000, 155)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
# hidden_dim = 500
num_classes = 10

#net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
results = {}
best_val = -1
batch_size = 256
num_iters = 1500

learning_rates = [1, 0.1]
regularization_strengths = [1e-7, 1e-4, 1e-5, 1e-6, 1e-7]
learning_rate_decays = [0.95, 0.99, 0.999]
hidden_dims = [300]

nets = {}

i = 0
for hidden_dim in hidden_dims:
    for decay in learning_rate_decays:
        for lr in learning_rates:
            for C in regularization_strengths:
                print('hidden_dim {}, decay {}, lr {}, C {}'.format(hidden_dim, decay, lr, C))
                print('Done {:2} out of {}'.format(i+1, len(hidden_dims)*len(learning_rates)*len(regularization_strengths)*len(learning_rate_decays)))

                # train
                net = TwoLayerNet(input_dim, hidden_dim, num_classes)
                net.train(X_train_feats, y_train, X_val_feats, y_val, num_iters=num_iters, 
                          batch_size=batch_size, learning_rate=lr, 
                          learning_rate_decay=decay, reg=C, verbose=True)

                # predict
                y_train_pred = net.predict(X_train_feats)
                y_val_pred = net.predict(X_val_feats)

                # scoring
                train_score = np.mean(y_train == y_train_pred)
                val_score = np.mean(y_val == y_val_pred)

                # store results
                results[(hidden_dim, decay, lr, C)] = (train_score, val_score)
                nets[(hidden_dim, decay, lr, C)] = net

                i += 1

sorted_results = sorted(results.items(), key=lambda x: x[1][1]) # by val score
best_params = sorted_results[-1][0]
best_val = sorted_results[-1][1][1]
best_net = nets[best_params]
print(best_net.hidden_dim, best_net.lr_decay, best_net.lr, best_net.C)

# Print out results.
for hidden_dim, decay, lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(hidden_dim, decay, lr, reg)]
    print('hidden_dim %e decay %e lr %e reg %e train accuracy: %f val accuracy: %f' % (
                hidden_dim, decay, lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# hidden_dim 300, decay 0.95, lr 1, C 1e-07
# Done  1 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 1.606418
# iteration 200 / 1500: loss 1.273257
# iteration 300 / 1500: loss 1.187152
# iteration 400 / 1500: loss 1.344690
# iteration 500 / 1500: loss 1.138074
# iteration 600 / 1500: loss 1.030942
# iteration 700 / 1500: loss 0.984312
# iteration 800 / 1500: loss 0.899282
# iteration 900 / 1500: loss 1.165166
# iteration 1000 / 1500: loss 0.995608
# iteration 1100 / 1500: loss 0.874285
# iteration 1200 / 1500: loss 0.862183
# iteration 1300 / 1500: loss 1.037495
# iteration 1400 / 1500: loss 0.719765
# hidden_dim 300, decay 0.95, lr 1, C 0.0001
# Done  2 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 1.414431
# iteration 200 / 1500: loss 1.336594
# iteration 300 / 1500: loss 1.255546
# iteration 400 / 1500: loss 1.264690
# iteration 500 / 1500: loss 1.199493
# iteration 600 / 1500: loss 1.144738
# iteration 700 / 1500: loss 1.060598
# iteration 800 / 1500: loss 0.951126
# iteration 900 / 1500: loss 1.078976
# iteration 1000 / 1500: loss 1.160495
# iteration 1100 / 1500: loss 0.959612
# iteration 1200 / 1500: loss 1.076489
# iteration 1300 / 1500: loss 1.026773
# iteration 1400 / 1500: loss 1.032954
# hidden_dim 300, decay 0.95, lr 1, C 1e-05
# Done  3 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 1.318288
# iteration 200 / 1500: loss 1.365460
# iteration 300 / 1500: loss 1.218710
# iteration 400 / 1500: loss 1.166736
# iteration 500 / 1500: loss 1.031058
# iteration 600 / 1500: loss 1.109428
# iteration 700 / 1500: loss 1.040362
# iteration 800 / 1500: loss 0.973224
# iteration 900 / 1500: loss 1.009438
# iteration 1000 / 1500: loss 1.014250
# iteration 1100 / 1500: loss 0.968441
# iteration 1200 / 1500: loss 0.937019
# iteration 1300 / 1500: loss 0.930133
# iteration 1400 / 1500: loss 0.742378
# hidden_dim 300, decay 0.95, lr 1, C 1e-06
# Done  4 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 1.443165
# iteration 200 / 1500: loss 1.405023
# iteration 300 / 1500: loss 1.313393
# iteration 400 / 1500: loss 1.071111
# iteration 500 / 1500: loss 1.220059
# iteration 600 / 1500: loss 1.015369
# iteration 700 / 1500: loss 0.996146
# iteration 800 / 1500: loss 0.832267
# iteration 900 / 1500: loss 0.983201
# iteration 1000 / 1500: loss 0.871090
# iteration 1100 / 1500: loss 0.846575
# iteration 1200 / 1500: loss 0.738617
# iteration 1300 / 1500: loss 0.810509
# iteration 1400 / 1500: loss 0.810831
# hidden_dim 300, decay 0.95, lr 1, C 1e-07
# Done  5 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 1.278461
# iteration 200 / 1500: loss 1.329042
# iteration 300 / 1500: loss 1.246111
# iteration 400 / 1500: loss 1.237707
# iteration 500 / 1500: loss 1.028518
# iteration 600 / 1500: loss 1.013930
# iteration 700 / 1500: loss 0.943747
# iteration 800 / 1500: loss 1.065369
# iteration 900 / 1500: loss 0.988986
# iteration 1000 / 1500: loss 0.916681
# iteration 1100 / 1500: loss 0.889921
# iteration 1200 / 1500: loss 0.740754
# iteration 1300 / 1500: loss 0.752854
# iteration 1400 / 1500: loss 0.809682
# hidden_dim 300, decay 0.95, lr 0.1, C 1e-07
# Done  6 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 2.303253
# iteration 200 / 1500: loss 2.152587
# iteration 300 / 1500: loss 1.754766
# iteration 400 / 1500: loss 1.548105
# iteration 500 / 1500: loss 1.495287
# iteration 600 / 1500: loss 1.384993
# iteration 700 / 1500: loss 1.449062
# iteration 800 / 1500: loss 1.379780
# iteration 900 / 1500: loss 1.399342
# iteration 1000 / 1500: loss 1.333446
# iteration 1100 / 1500: loss 1.255092
# iteration 1200 / 1500: loss 1.281702
# iteration 1300 / 1500: loss 1.371978
# iteration 1400 / 1500: loss 1.273560
# hidden_dim 300, decay 0.95, lr 0.1, C 0.0001
# Done  7 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 2.303083
# iteration 200 / 1500: loss 2.140896
# iteration 300 / 1500: loss 1.814190
# iteration 400 / 1500: loss 1.569885
# iteration 500 / 1500: loss 1.433162
# iteration 600 / 1500: loss 1.399140
# iteration 700 / 1500: loss 1.384763
# iteration 800 / 1500: loss 1.277117
# iteration 900 / 1500: loss 1.286467
# iteration 1000 / 1500: loss 1.255954
# iteration 1100 / 1500: loss 1.389308
# iteration 1200 / 1500: loss 1.266037
# iteration 1300 / 1500: loss 1.304774
# iteration 1400 / 1500: loss 1.355400
# hidden_dim 300, decay 0.95, lr 0.1, C 1e-05
# Done  8 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 2.302831
# iteration 200 / 1500: loss 2.163801
# iteration 300 / 1500: loss 1.703026
# iteration 400 / 1500: loss 1.535132
# iteration 500 / 1500: loss 1.555496
# iteration 600 / 1500: loss 1.444469
# iteration 700 / 1500: loss 1.400599
# iteration 800 / 1500: loss 1.447398
# iteration 900 / 1500: loss 1.285454
# iteration 1000 / 1500: loss 1.314483
# iteration 1100 / 1500: loss 1.266292
# iteration 1200 / 1500: loss 1.233989
# iteration 1300 / 1500: loss 1.271476
# iteration 1400 / 1500: loss 1.280422
# hidden_dim 300, decay 0.95, lr 0.1, C 1e-06
# Done  9 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 2.302414
# iteration 200 / 1500: loss 2.193188
# iteration 300 / 1500: loss 1.828935
# iteration 400 / 1500: loss 1.630130
# iteration 500 / 1500: loss 1.529920
# iteration 600 / 1500: loss 1.344071
# iteration 700 / 1500: loss 1.476671
# iteration 800 / 1500: loss 1.292859
# iteration 900 / 1500: loss 1.356749
# iteration 1000 / 1500: loss 1.363770
# iteration 1100 / 1500: loss 1.365396
# iteration 1200 / 1500: loss 1.276033
# iteration 1300 / 1500: loss 1.320901
# iteration 1400 / 1500: loss 1.302011
# hidden_dim 300, decay 0.95, lr 0.1, C 1e-07
# Done 10 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 2.302061
# iteration 200 / 1500: loss 2.162827
# iteration 300 / 1500: loss 1.720179
# iteration 400 / 1500: loss 1.565771
# iteration 500 / 1500: loss 1.588962
# iteration 600 / 1500: loss 1.363342
# iteration 700 / 1500: loss 1.370330
# iteration 800 / 1500: loss 1.352647
# iteration 900 / 1500: loss 1.335451
# iteration 1000 / 1500: loss 1.308842
# iteration 1100 / 1500: loss 1.196337
# iteration 1200 / 1500: loss 1.317132
# iteration 1300 / 1500: loss 1.312885
# iteration 1400 / 1500: loss 1.223700
# hidden_dim 300, decay 0.99, lr 1, C 1e-07
# Done 11 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 1.350884
# iteration 200 / 1500: loss 1.407724
# iteration 300 / 1500: loss 1.301511
# iteration 400 / 1500: loss 1.288981
# iteration 500 / 1500: loss 1.205182
# iteration 600 / 1500: loss 0.979875
# iteration 700 / 1500: loss 1.009003
# iteration 800 / 1500: loss 1.067800
# iteration 900 / 1500: loss 1.021338
# iteration 1000 / 1500: loss 1.073942
# iteration 1100 / 1500: loss 0.998531
# iteration 1200 / 1500: loss 0.883192
# iteration 1300 / 1500: loss 0.836744
# iteration 1400 / 1500: loss 0.833184
# hidden_dim 300, decay 0.99, lr 1, C 0.0001
# Done 12 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 1.462464
# iteration 200 / 1500: loss 1.400923
# iteration 300 / 1500: loss 1.201505
# iteration 400 / 1500: loss 1.210446
# iteration 500 / 1500: loss 1.186694
# iteration 600 / 1500: loss 1.115752
# iteration 700 / 1500: loss 0.959651
# iteration 800 / 1500: loss 0.974339
# iteration 900 / 1500: loss 1.009922
# iteration 1000 / 1500: loss 0.917479
# iteration 1100 / 1500: loss 0.855307
# iteration 1200 / 1500: loss 0.886534
# iteration 1300 / 1500: loss 0.979926
# iteration 1400 / 1500: loss 0.842367
# hidden_dim 300, decay 0.99, lr 1, C 1e-05
# Done 13 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 1.270237
# iteration 200 / 1500: loss 1.344706
# iteration 300 / 1500: loss 1.350439
# iteration 400 / 1500: loss 1.271745
# iteration 500 / 1500: loss 1.019213
# iteration 600 / 1500: loss 1.161881
# iteration 700 / 1500: loss 0.941274
# iteration 800 / 1500: loss 0.943247
# iteration 900 / 1500: loss 1.021918
# iteration 1000 / 1500: loss 0.943808
# iteration 1100 / 1500: loss 1.114115
# iteration 1200 / 1500: loss 0.835287
# iteration 1300 / 1500: loss 0.870605
# iteration 1400 / 1500: loss 0.758468
# hidden_dim 300, decay 0.99, lr 1, C 1e-06
# Done 14 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 1.433495
# iteration 200 / 1500: loss 1.463253
# iteration 300 / 1500: loss 1.290243
# iteration 400 / 1500: loss 1.235615
# iteration 500 / 1500: loss 1.206982
# iteration 600 / 1500: loss 1.008716
# iteration 700 / 1500: loss 1.016480
# iteration 800 / 1500: loss 1.099892
# iteration 900 / 1500: loss 0.992106
# iteration 1000 / 1500: loss 0.910087
# iteration 1100 / 1500: loss 0.935227
# iteration 1200 / 1500: loss 0.826660
# iteration 1300 / 1500: loss 0.807174
# iteration 1400 / 1500: loss 0.824390
# hidden_dim 300, decay 0.99, lr 1, C 1e-07
# Done 15 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 1.658985
# iteration 200 / 1500: loss 1.384796
# iteration 300 / 1500: loss 1.299617
# iteration 400 / 1500: loss 1.296944
# iteration 500 / 1500: loss 1.127334
# iteration 600 / 1500: loss 1.015316
# iteration 700 / 1500: loss 0.985360
# iteration 800 / 1500: loss 0.986043
# iteration 900 / 1500: loss 1.025301
# iteration 1000 / 1500: loss 0.963640
# iteration 1100 / 1500: loss 1.001160
# iteration 1200 / 1500: loss 0.993190
# iteration 1300 / 1500: loss 0.836338
# iteration 1400 / 1500: loss 0.902831
# hidden_dim 300, decay 0.99, lr 0.1, C 1e-07
# Done 16 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 2.302028
# iteration 200 / 1500: loss 2.128287
# iteration 300 / 1500: loss 1.798201
# iteration 400 / 1500: loss 1.534493
# iteration 500 / 1500: loss 1.517193
# iteration 600 / 1500: loss 1.340523
# iteration 700 / 1500: loss 1.335124
# iteration 800 / 1500: loss 1.405640
# iteration 900 / 1500: loss 1.396006
# iteration 1000 / 1500: loss 1.396669
# iteration 1100 / 1500: loss 1.435507
# iteration 1200 / 1500: loss 1.265181
# iteration 1300 / 1500: loss 1.212028
# iteration 1400 / 1500: loss 1.377976
# hidden_dim 300, decay 0.99, lr 0.1, C 0.0001
# Done 17 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 2.303325
# iteration 200 / 1500: loss 2.115718
# iteration 300 / 1500: loss 1.757214
# iteration 400 / 1500: loss 1.560609
# iteration 500 / 1500: loss 1.421522
# iteration 600 / 1500: loss 1.523300
# iteration 700 / 1500: loss 1.462286
# iteration 800 / 1500: loss 1.375468
# iteration 900 / 1500: loss 1.306467
# iteration 1000 / 1500: loss 1.408630
# iteration 1100 / 1500: loss 1.347712
# iteration 1200 / 1500: loss 1.195517
# iteration 1300 / 1500: loss 1.256016
# iteration 1400 / 1500: loss 1.286506
# hidden_dim 300, decay 0.99, lr 0.1, C 1e-05
# Done 18 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 2.301127
# iteration 200 / 1500: loss 2.108761
# iteration 300 / 1500: loss 1.794121
# iteration 400 / 1500: loss 1.562022
# iteration 500 / 1500: loss 1.436341
# iteration 600 / 1500: loss 1.520819
# iteration 700 / 1500: loss 1.474137
# iteration 800 / 1500: loss 1.181599
# iteration 900 / 1500: loss 1.548478
# iteration 1000 / 1500: loss 1.365675
# iteration 1100 / 1500: loss 1.326976
# iteration 1200 / 1500: loss 1.387275
# iteration 1300 / 1500: loss 1.324500
# iteration 1400 / 1500: loss 1.155840
# hidden_dim 300, decay 0.99, lr 0.1, C 1e-06
# Done 19 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 2.302059
# iteration 200 / 1500: loss 2.090593
# iteration 300 / 1500: loss 1.801337
# iteration 400 / 1500: loss 1.663758
# iteration 500 / 1500: loss 1.454588
# iteration 600 / 1500: loss 1.334348
# iteration 700 / 1500: loss 1.306943
# iteration 800 / 1500: loss 1.359219
# iteration 900 / 1500: loss 1.350290
# iteration 1000 / 1500: loss 1.315456
# iteration 1100 / 1500: loss 1.343530
# iteration 1200 / 1500: loss 1.314386
# iteration 1300 / 1500: loss 1.326089
# iteration 1400 / 1500: loss 1.315987
# hidden_dim 300, decay 0.99, lr 0.1, C 1e-07
# Done 20 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 2.302049
# iteration 200 / 1500: loss 2.155215
# iteration 300 / 1500: loss 1.724990
# iteration 400 / 1500: loss 1.598327
# iteration 500 / 1500: loss 1.537602
# iteration 600 / 1500: loss 1.343965
# iteration 700 / 1500: loss 1.397450
# iteration 800 / 1500: loss 1.279912
# iteration 900 / 1500: loss 1.357654
# iteration 1000 / 1500: loss 1.319058
# iteration 1100 / 1500: loss 1.322662
# iteration 1200 / 1500: loss 1.261594
# iteration 1300 / 1500: loss 1.254647
# iteration 1400 / 1500: loss 1.424211
# hidden_dim 300, decay 0.999, lr 1, C 1e-07
# Done 21 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 1.470690
# iteration 200 / 1500: loss 1.292631
# iteration 300 / 1500: loss 1.220907
# iteration 400 / 1500: loss 1.120407
# iteration 500 / 1500: loss 1.079798
# iteration 600 / 1500: loss 1.051578
# iteration 700 / 1500: loss 0.998862
# iteration 800 / 1500: loss 0.986398
# iteration 900 / 1500: loss 1.052539
# iteration 1000 / 1500: loss 0.949309
# iteration 1100 / 1500: loss 1.165342
# iteration 1200 / 1500: loss 1.006875
# iteration 1300 / 1500: loss 0.972432
# iteration 1400 / 1500: loss 0.805367
# hidden_dim 300, decay 0.999, lr 1, C 0.0001
# Done 22 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 1.435581
# iteration 200 / 1500: loss 1.388655
# iteration 300 / 1500: loss 1.243776
# iteration 400 / 1500: loss 1.200736
# iteration 500 / 1500: loss 1.116467
# iteration 600 / 1500: loss 1.146461
# iteration 700 / 1500: loss 1.049187
# iteration 800 / 1500: loss 1.044581
# iteration 900 / 1500: loss 1.051684
# iteration 1000 / 1500: loss 0.929084
# iteration 1100 / 1500: loss 1.019314
# iteration 1200 / 1500: loss 1.184802
# iteration 1300 / 1500: loss 0.860684
# iteration 1400 / 1500: loss 0.865792
# hidden_dim 300, decay 0.999, lr 1, C 1e-05
# Done 23 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 1.467126
# iteration 200 / 1500: loss 1.330941
# iteration 300 / 1500: loss 1.317827
# iteration 400 / 1500: loss 1.101715
# iteration 500 / 1500: loss 1.098563
# iteration 600 / 1500: loss 1.244828
# iteration 700 / 1500: loss 0.996493
# iteration 800 / 1500: loss 0.983476
# iteration 900 / 1500: loss 0.975666
# iteration 1000 / 1500: loss 0.857851
# iteration 1100 / 1500: loss 0.891324
# iteration 1200 / 1500: loss 1.017862
# iteration 1300 / 1500: loss 0.847287
# iteration 1400 / 1500: loss 0.823394
# hidden_dim 300, decay 0.999, lr 1, C 1e-06
# Done 24 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 1.404737
# iteration 200 / 1500: loss 1.295474
# iteration 300 / 1500: loss 1.228471
# iteration 400 / 1500: loss 1.074537
# iteration 500 / 1500: loss 1.135760
# iteration 600 / 1500: loss 1.062504
# iteration 700 / 1500: loss 0.899234
# iteration 800 / 1500: loss 1.060522
# iteration 900 / 1500: loss 0.987343
# iteration 1000 / 1500: loss 0.917443
# iteration 1100 / 1500: loss 0.982407
# iteration 1200 / 1500: loss 0.899387
# iteration 1300 / 1500: loss 0.979748
# iteration 1400 / 1500: loss 0.880489
# hidden_dim 300, decay 0.999, lr 1, C 1e-07
# Done 25 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 1.559316
# iteration 200 / 1500: loss 1.240366
# iteration 300 / 1500: loss 1.168094
# iteration 400 / 1500: loss 1.218507
# iteration 500 / 1500: loss 1.140307
# iteration 600 / 1500: loss 1.130812
# iteration 700 / 1500: loss 1.167179
# iteration 800 / 1500: loss 0.933949
# iteration 900 / 1500: loss 1.051595
# iteration 1000 / 1500: loss 0.912704
# iteration 1100 / 1500: loss 1.008409
# iteration 1200 / 1500: loss 0.852777
# iteration 1300 / 1500: loss 0.922409
# iteration 1400 / 1500: loss 0.746522
# hidden_dim 300, decay 0.999, lr 0.1, C 1e-07
# Done 26 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 2.303249
# iteration 200 / 1500: loss 2.110687
# iteration 300 / 1500: loss 1.754244
# iteration 400 / 1500: loss 1.693387
# iteration 500 / 1500: loss 1.483689
# iteration 600 / 1500: loss 1.432689
# iteration 700 / 1500: loss 1.303503
# iteration 800 / 1500: loss 1.314523
# iteration 900 / 1500: loss 1.292945
# iteration 1000 / 1500: loss 1.253381
# iteration 1100 / 1500: loss 1.339769
# iteration 1200 / 1500: loss 1.261490
# iteration 1300 / 1500: loss 1.334153
# iteration 1400 / 1500: loss 1.202046
# hidden_dim 300, decay 0.999, lr 0.1, C 0.0001
# Done 27 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 2.300846
# iteration 200 / 1500: loss 2.107067
# iteration 300 / 1500: loss 1.802844
# iteration 400 / 1500: loss 1.528436
# iteration 500 / 1500: loss 1.496174
# iteration 600 / 1500: loss 1.392551
# iteration 700 / 1500: loss 1.406764
# iteration 800 / 1500: loss 1.310137
# iteration 900 / 1500: loss 1.329797
# iteration 1000 / 1500: loss 1.242574
# iteration 1100 / 1500: loss 1.378808
# iteration 1200 / 1500: loss 1.274375
# iteration 1300 / 1500: loss 1.342480
# iteration 1400 / 1500: loss 1.401685
# hidden_dim 300, decay 0.999, lr 0.1, C 1e-05
# Done 28 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 2.301404
# iteration 200 / 1500: loss 2.139117
# iteration 300 / 1500: loss 1.795996
# iteration 400 / 1500: loss 1.684925
# iteration 500 / 1500: loss 1.403301
# iteration 600 / 1500: loss 1.524043
# iteration 700 / 1500: loss 1.401193
# iteration 800 / 1500: loss 1.317487
# iteration 900 / 1500: loss 1.344981
# iteration 1000 / 1500: loss 1.308493
# iteration 1100 / 1500: loss 1.317660
# iteration 1200 / 1500: loss 1.190650
# iteration 1300 / 1500: loss 1.314051
# iteration 1400 / 1500: loss 1.278685
# hidden_dim 300, decay 0.999, lr 0.1, C 1e-06
# Done 29 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 2.302324
# iteration 200 / 1500: loss 2.128872
# iteration 300 / 1500: loss 1.758698
# iteration 400 / 1500: loss 1.604269
# iteration 500 / 1500: loss 1.476899
# iteration 600 / 1500: loss 1.401945
# iteration 700 / 1500: loss 1.337913
# iteration 800 / 1500: loss 1.303846
# iteration 900 / 1500: loss 1.268024
# iteration 1000 / 1500: loss 1.498145
# iteration 1100 / 1500: loss 1.385398
# iteration 1200 / 1500: loss 1.193628
# iteration 1300 / 1500: loss 1.353114
# iteration 1400 / 1500: loss 1.332081
# hidden_dim 300, decay 0.999, lr 0.1, C 1e-07
# Done 30 out of 30
# iteration 0 / 1500: loss 2.302585
# iteration 100 / 1500: loss 2.301715
# iteration 200 / 1500: loss 2.083167
# iteration 300 / 1500: loss 1.767332
# iteration 400 / 1500: loss 1.460823
# iteration 500 / 1500: loss 1.439778
# iteration 600 / 1500: loss 1.436436
# iteration 700 / 1500: loss 1.365137
# iteration 800 / 1500: loss 1.294577
# iteration 900 / 1500: loss 1.386114
# iteration 1000 / 1500: loss 1.192925
# iteration 1100 / 1500: loss 1.240245
# iteration 1200 / 1500: loss 1.378101
# iteration 1300 / 1500: loss 1.242137
# iteration 1400 / 1500: loss 1.136968
# 300 0.99 0.99 1e-05
# hidden_dim 3.000000e+02 decay 9.500000e-01 lr 1.000000e-01 reg 1.000000e-07 train accuracy: 0.548796 val accuracy: 0.529000
# hidden_dim 3.000000e+02 decay 9.500000e-01 lr 1.000000e-01 reg 1.000000e-06 train accuracy: 0.546122 val accuracy: 0.535000
# hidden_dim 3.000000e+02 decay 9.500000e-01 lr 1.000000e-01 reg 1.000000e-05 train accuracy: 0.548163 val accuracy: 0.524000
# hidden_dim 3.000000e+02 decay 9.500000e-01 lr 1.000000e-01 reg 1.000000e-04 train accuracy: 0.548367 val accuracy: 0.525000
# hidden_dim 3.000000e+02 decay 9.500000e-01 lr 1.000000e+00 reg 1.000000e-07 train accuracy: 0.724163 val accuracy: 0.557000
# hidden_dim 3.000000e+02 decay 9.500000e-01 lr 1.000000e+00 reg 1.000000e-06 train accuracy: 0.721878 val accuracy: 0.557000
# hidden_dim 3.000000e+02 decay 9.500000e-01 lr 1.000000e+00 reg 1.000000e-05 train accuracy: 0.727490 val accuracy: 0.573000
# hidden_dim 3.000000e+02 decay 9.500000e-01 lr 1.000000e+00 reg 1.000000e-04 train accuracy: 0.713612 val accuracy: 0.554000
# hidden_dim 3.000000e+02 decay 9.900000e-01 lr 1.000000e-01 reg 1.000000e-07 train accuracy: 0.552061 val accuracy: 0.524000
# hidden_dim 3.000000e+02 decay 9.900000e-01 lr 1.000000e-01 reg 1.000000e-06 train accuracy: 0.550959 val accuracy: 0.533000
# hidden_dim 3.000000e+02 decay 9.900000e-01 lr 1.000000e-01 reg 1.000000e-05 train accuracy: 0.551082 val accuracy: 0.532000
# hidden_dim 3.000000e+02 decay 9.900000e-01 lr 1.000000e-01 reg 1.000000e-04 train accuracy: 0.550224 val accuracy: 0.531000
# hidden_dim 3.000000e+02 decay 9.900000e-01 lr 1.000000e+00 reg 1.000000e-07 train accuracy: 0.723714 val accuracy: 0.567000
# hidden_dim 3.000000e+02 decay 9.900000e-01 lr 1.000000e+00 reg 1.000000e-06 train accuracy: 0.708347 val accuracy: 0.554000
# hidden_dim 3.000000e+02 decay 9.900000e-01 lr 1.000000e+00 reg 1.000000e-05 train accuracy: 0.724469 val accuracy: 0.582000
# hidden_dim 3.000000e+02 decay 9.900000e-01 lr 1.000000e+00 reg 1.000000e-04 train accuracy: 0.705122 val accuracy: 0.552000
# hidden_dim 3.000000e+02 decay 9.990000e-01 lr 1.000000e-01 reg 1.000000e-07 train accuracy: 0.552551 val accuracy: 0.530000
# hidden_dim 3.000000e+02 decay 9.990000e-01 lr 1.000000e-01 reg 1.000000e-06 train accuracy: 0.551490 val accuracy: 0.533000
# hidden_dim 3.000000e+02 decay 9.990000e-01 lr 1.000000e-01 reg 1.000000e-05 train accuracy: 0.549612 val accuracy: 0.532000
# hidden_dim 3.000000e+02 decay 9.990000e-01 lr 1.000000e-01 reg 1.000000e-04 train accuracy: 0.550041 val accuracy: 0.529000
# hidden_dim 3.000000e+02 decay 9.990000e-01 lr 1.000000e+00 reg 1.000000e-07 train accuracy: 0.730327 val accuracy: 0.574000
# hidden_dim 3.000000e+02 decay 9.990000e-01 lr 1.000000e+00 reg 1.000000e-06 train accuracy: 0.724367 val accuracy: 0.570000
# hidden_dim 3.000000e+02 decay 9.990000e-01 lr 1.000000e+00 reg 1.000000e-05 train accuracy: 0.713878 val accuracy: 0.571000
# hidden_dim 3.000000e+02 decay 9.990000e-01 lr 1.000000e+00 reg 1.000000e-04 train accuracy: 0.700102 val accuracy: 0.568000
# best validation accuracy achieved during cross-validation: 0.582000

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.563

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
